# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
geodistk_path = "/content/drive/MyDrive/Course/研一上/深度學習之於生醫/final presentation/MIDeepSeg-master"

# %%
# %cd /content/drive/MyDrive/Course/研一上/深度學習之於生醫/final presentation/MIDeepSeg-master
# %pwd
# Out:
# /content/drive/MyDrive/Course/研一上/深度學習之於生醫/final presentation/MIDeepSeg-master
# '/content/drive/MyDrive/Course/研一上/深度學習之於生醫/final presentation/MIDeepSeg-master'

# %%
# !pip freeze | grep scikit_image
# !pip freeze | grep SimpleCRF
# !pip freeze | grep scipy
# !pip freeze | grep GeodisTK
# !pip freeze | grep maxflow
# !pip freeze | grep Pillow
# !pip freeze | grep PyQt5
# Out:
# scipy==1.11.4
# maxflow==0.0.1
# Pillow==9.4.0

# %%
# !pip install scikit_image
# !pip install SimpleCRF
# !pip install scipy
# !pip install GeodisTK
# !pip install maxflow
# !pip install Pillow
# !pip install PyQt5
# Out:
# ...
#   Using cached SimpleCRF-0.2.1.1.tar.gz (2.7 MB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for SimpleCRF: filename=SimpleCRF-0.2.1.1-cp310-cp310-linux_x86_64.whl size=6618111 sha256=76dc779e56f3a98a97da6b84507f8fdd7ee2ae002d02e0944dd29c4e70c5002a
#   Stored in directory: /root/.cache/pip/wheels/58/ee/bc/adc95b6b092ad308d579cc398f0cdeec9a31e6f6f57d23c594
# Successfully built SimpleCRF
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for GeodisTK: filename=GeodisTK-0.1.7-cp310-cp310-linux_x86_64.whl size=186876 sha256=ff455fe34211e7aa628f2f1fa86901628f837f67e2f0b5a835d8491509c43b71
#   Stored in directory: /root/.cache/pip/wheels/f2/12/43/7a79927d541a85dc3fe26c3a0e718a01c4e0074855bf9c8941
# Successfully built GeodisTK
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 27.1 MB/s eta 0:00:00
# ...

# %%
# %pwd
# Out:
# '/content/drive/MyDrive/Course/研一上/深度學習之於生醫/final presentation/MIDeepSeg-master'

# %%
# %cd mideepseg
# !python main.py
# Out:
# /content/drive/MyDrive/Course/研一上/深度學習之於生醫/final presentation/MIDeepSeg-master/mideepseg
# QObject::moveToThread: Current thread (0x557ae5280de0) is not the object's thread (0x557aec1d2650).
# Cannot move to target thread (0x557ae5280de0)
#
# qt.qpa.plugin: Could not load the Qt platform plugin "xcb" in "/usr/local/lib/python3.10/dist-packages/cv2/qt/plugins" even though it was found.
# This application failed to start because no Qt platform plugin could be initialized. Reinstalling the application may fix this problem.
#
# Available platform plugins are: xcb, eglfs, linuxfb, minimal, minimalegl, offscreen, vnc, wayland-egl, wayland, wayland-xcomposite-egl, wayland-xcomposite-glx, webgl.

# %%
# !sudo apt-get update
# !sudo apt-get install -y libxcb-xinerama0
# !sudo apt-get install -y libxcb-xkb1
# Out:
# Get:1 http://security.ubuntu.com/ubuntu jammy-security InRelease [110 kB]
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Get:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [634 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [119 kB]
# Get:7 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [1,325 kB]
# Hit:8 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease
# Get:9 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [1,572 kB]
# Get:10 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,036 kB]
# Hit:11 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# ...

# %%
# !python main.py
# Out:
# QObject::moveToThread: Current thread (0x5a54f1a77de0) is not the object's thread (0x5a54f89c6d30).
# Cannot move to target thread (0x5a54f1a77de0)
#
# qt.qpa.plugin: Could not load the Qt platform plugin "xcb" in "/usr/local/lib/python3.10/dist-packages/cv2/qt/plugins" even though it was found.
# This application failed to start because no Qt platform plugin could be initialized. Reinstalling the application may fix this problem.
#
# Available platform plugins are: xcb, eglfs, linuxfb, minimal, minimalegl, offscreen, vnc, wayland-egl, wayland, wayland-xcomposite-egl, wayland-xcomposite-glx, webgl.
